# %%
# importing packages
import numpy as np
import pandas as pd
import sqlite3
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#retrieving dataframes
# %store -r gross
# %store -r info
# %store -r reviews
# %store -r tmdb
# %store -r budgets
# %store -r movie_basics
# %store -r movie_ratings
# %store -r movie_genres

# %%
movie_genres
# Out:
#        movie_id                 genre   table_match
# 0         63540                   NaN  movie_basics
# 1         66787                   NaN  movie_basics
# 2         69049                 Drama  movie_basics
# 3         69204                   NaN  movie_basics
# 4        100275                   NaN  movie_basics
# ...         ...                   ...           ...
# 47827    381231  Action and Adventure          tmdb
# 47829    366854       Kids and Family          tmdb
# 47830    366854  Action and Adventure          tmdb
# 47832    309885  Mystery and Suspense          tmdb
# 47833    309885                Horror          tmdb
#
# [193909 rows x 3 columns]

# %%
#selecting only rows where table_match = movie_basics
mbg= movie_genres.loc[(movie_genres.table_match == "movie_basics")]
mbg
# Out:
#         movie_id        genre   table_match
# 0          63540          NaN  movie_basics
# 1          66787          NaN  movie_basics
# 2          69049        Drama  movie_basics
# 3          69204          NaN  movie_basics
# 4         100275          NaN  movie_basics
# ...          ...          ...           ...
# 146139   9916538        Drama  movie_basics
# 146140   9916622  Documentary  movie_basics
# 146141   9916706       Comedy  movie_basics
# 146142   9916730          NaN  movie_basics
# 146143   9916754  Documentary  movie_basics
#
# [146144 rows x 3 columns]

# %%
#combining movie_basics with movie_reviews
movieBasicRating = movie_basics.merge(movie_ratings, on = 'movie_id')
movieBasicRating
# Out:
#        movie_id                    primary_title              original_title  \
# 0         63540                        Sunghursh                   Sunghursh
# 1         66787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2         69049       The Other Side of the Wind  The Other Side of the Wind
# 3         69204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4        100275         The Wandering Soap Opera       La Telenovela Errante
# ...         ...                              ...                         ...
# 73851   9913084                 Diabolik sono io            Diabolik sono io
# 73852   9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853   9914642                        Albatross                   Albatross
# 73854   9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855   9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes  averagerating  numvotes
# 0            2013            175.0            7.0        77
# 1            2019            114.0            7.2        43
# 2            2018            122.0            6.9      4517
# 3            2018              NaN            6.1        13
# 4            2017             80.0            6.5       119
# ...           ...              ...            ...       ...
# 73851        2019             75.0            6.2         6
# 73852        2019             98.0            8.7       136
# 73853        2017              NaN            8.5         8
# 73854        2019              NaN            6.6         5
# 73855        2019             72.0            6.5        11
#
# [73856 rows x 7 columns]

# %%
#combining the movieBasicsGenres table with movieBasicRating table
movieBasicsGenres = mbg.merge(movieBasicRating, on = 'movie_id')
movieBasicsGenres
# Out:
#        movie_id        genre   table_match                    primary_title  \
# 0         63540          NaN  movie_basics                        Sunghursh
# 1         66787          NaN  movie_basics  One Day Before the Rainy Season
# 2         69049        Drama  movie_basics       The Other Side of the Wind
# 3         69204          NaN  movie_basics                  Sabse Bada Sukh
# 4        100275          NaN  movie_basics         The Wandering Soap Opera
# ...         ...          ...           ...                              ...
# 73851   9913084  Documentary  movie_basics                 Diabolik sono io
# 73852   9914286          NaN  movie_basics                Sokagin Çocuklari
# 73853   9914642  Documentary  movie_basics                        Albatross
# 73854   9914942          NaN  movie_basics       La vida sense la Sara Amat
# 73855   9916160  Documentary  movie_basics                       Drømmeland
#
#                    original_title  start_year  runtime_minutes  averagerating  \
# 0                       Sunghursh        2013            175.0            7.0
# 1                 Ashad Ka Ek Din        2019            114.0            7.2
# 2      The Other Side of the Wind        2018            122.0            6.9
# 3                 Sabse Bada Sukh        2018              NaN            6.1
# 4           La Telenovela Errante        2017             80.0            6.5
# ...                           ...         ...              ...            ...
# 73851            Diabolik sono io        2019             75.0            6.2
# 73852           Sokagin Çocuklari        2019             98.0            8.7
# 73853                   Albatross        2017              NaN            8.5
# 73854  La vida sense la Sara Amat        2019              NaN            6.6
# 73855                  Drømmeland        2019             72.0            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73851         6
# 73852       136
# 73853         8
# 73854         5
# 73855        11
#
# [73856 rows x 9 columns]

# %%
#dropping unwanted columns 
genreRankings = movieBasicsGenres[['movie_id', 'genre', 'primary_title', 'averagerating', 'numvotes']]
genreRankings

#drop rows where genre is null 
gR = genreRankings.dropna()
gR.value_counts('genre')
# Out:
# genre
# Drama                          11612
# Documentary                    10313
# Comedy                          5613
# Horror                          2692
# Mystery and Suspense            2012
# Action and Adventure            1202
# Romance                          717
# Kids and Family                  491
# Science Fiction and Fantasy      442
# Animation                        348
# Music                            308
# Biography                        163
# History                          106
# Sports and Fitness                88
# Western                           75
# TV Show                           10
# dtype: int64

# %%
#getting the average rating of movies in each genre
gRGrouped = gR.groupby('genre').mean().reset_index()
gRGrouped

#deleting unwanted columns 
gRg = gRGrouped[['genre', 'averagerating']]

#changing column name 
rating = gRg.rename(columns ={"averagerating":"averageRatingPerGenre"})
rating
# Out:
#                           genre  averageRatingPerGenre
# 0          Action and Adventure               5.847837
# 1                     Animation               5.908621
# 2                     Biography               6.858896
# 3                        Comedy               5.777998
# 4                   Documentary               7.293794
# 5                         Drama               6.494265
# 6                       History               6.605660
# 7                        Horror               4.835475
# 8               Kids and Family               6.078004
# 9                         Music               7.241558
# 10         Mystery and Suspense               5.794732
# 11                      Romance               6.051883
# 12  Science Fiction and Fantasy               5.693665
# 13           Sports and Fitness               6.956818
# 14                      TV Show               6.000000
# 15                      Western               5.037333

# %%
#getting the count of movies in each genre
gRCount =gR.groupby('genre').count().reset_index()
gRCount

#dropping unnecessary columns 
gRc = gRCount[['genre', 'movie_id']]
gRc

#changing column name 
count = gRc.rename(columns ={"movie_id":"count"})
count
# Out:
#                           genre  count
# 0          Action and Adventure   1202
# 1                     Animation    348
# 2                     Biography    163
# 3                        Comedy   5613
# 4                   Documentary  10313
# 5                         Drama  11612
# 6                       History    106
# 7                        Horror   2692
# 8               Kids and Family    491
# 9                         Music    308
# 10         Mystery and Suspense   2012
# 11                      Romance    717
# 12  Science Fiction and Fantasy    442
# 13           Sports and Fitness     88
# 14                      TV Show     10
# 15                      Western     75

# %%
#combining table with average rating and count per genre
genreRat = count.merge(rating, on = 'genre')
genreRat
# Out:
#                           genre  count  averageRatingPerGenre
# 0          Action and Adventure   1202               5.847837
# 1                     Animation    348               5.908621
# 2                     Biography    163               6.858896
# 3                        Comedy   5613               5.777998
# 4                   Documentary  10313               7.293794
# 5                         Drama  11612               6.494265
# 6                       History    106               6.605660
# 7                        Horror   2692               4.835475
# 8               Kids and Family    491               6.078004
# 9                         Music    308               7.241558
# 10         Mystery and Suspense   2012               5.794732
# 11                      Romance    717               6.051883
# 12  Science Fiction and Fantasy    442               5.693665
# 13           Sports and Fitness     88               6.956818
# 14                      TV Show     10               6.000000
# 15                      Western     75               5.037333

# %%
#renaming genre column
genreRatingCount = genreRat.rename(columns ={"genre":"Genre"})
genreRatingCount
# Out:
#                           Genre  count  averageRatingPerGenre
# 0          Action and Adventure   1202               5.847837
# 1                     Animation    348               5.908621
# 2                     Biography    163               6.858896
# 3                        Comedy   5613               5.777998
# 4                   Documentary  10313               7.293794
# 5                         Drama  11612               6.494265
# 6                       History    106               6.605660
# 7                        Horror   2692               4.835475
# 8               Kids and Family    491               6.078004
# 9                         Music    308               7.241558
# 10         Mystery and Suspense   2012               5.794732
# 11                      Romance    717               6.051883
# 12  Science Fiction and Fantasy    442               5.693665
# 13           Sports and Fitness     88               6.956818
# 14                      TV Show     10               6.000000
# 15                      Western     75               5.037333

# %%
####showing all Genres

# %%
#creating a scatterplot of all genres
AB = sns.scatterplot(data=genreRatingCount, x='averageRatingPerGenre', y='count')
AB.set(xlabel = "Average Rating of Movies",
      ylabel = "Number of Movies",
      title = "Analysis of all Genres")
#exporting plot
plt.savefig("ALLgenres.png")

# %%
######showing genres with average score > 6.5 and count < 350

# %%
#creating a scatterplot when average ratings are > 6.5

#filtering movies with rating > 6 .5
filter = genreRatingCount['averageRatingPerGenre'] > 6.5
topRankings= genreRatingCount[filter]
print(topRankings)
# Out:
#                  Genre  count  averageRatingPerGenre
# 2            Biography    163               6.858896
# 4          Documentary  10313               7.293794
# 6              History    106               6.605660
# 9                Music    308               7.241558
# 13  Sports and Fitness     88               6.956818

# %%
#filtering movies with count < 10000
filt = topRankings['count']< 350
topGenres =topRankings[filt]
print(topGenres)
# Out:
#                  Genre  count  averageRatingPerGenre
# 2            Biography    163               6.858896
# 6              History    106               6.605660
# 9                Music    308               7.241558
# 13  Sports and Fitness     88               6.956818

# %%
#creating a scatterplot of the top 5 genres
ax = sns.scatterplot(data=topGenres,
                x='averageRatingPerGenre',
                y='count', 
                hue = 'Genre')

ax.set(xlabel = "Average Rating of Movies",
      ylabel = "Number of Movies",
      title = "Filtered Genre Analysis")
#exporting plot
plt.savefig("specificGenres.png")

# %%
########Hypothesis Testing

# %%
#H_0: Movies that fall in the music genre do not have 
# higher average rating than movies in other genres

#H_1: Movies that fall in the music genre have significantly higher
## average ratings compared to other movie genres

# %%
#using the ungrouped df
gR
# Out:
#        movie_id        genre                       primary_title  \
# 2         69049        Drama          The Other Side of the Wind
# 7        146592        Drama                         Pál Adrienn
# 8        154039      History                So Much for Justice!
# 9        159369  Documentary  Cooper and Hemingway: The True Gen
# 10       162942        Drama        Children of the Green Dragon
# ...         ...          ...                                 ...
# 73849   9911774        Drama           Padmavyuhathile Abhimanyu
# 73850   9913056  Documentary                        Swarm Season
# 73851   9913084  Documentary                    Diabolik sono io
# 73853   9914642  Documentary                           Albatross
# 73855   9916160  Documentary                          Drømmeland
#
#        averagerating  numvotes
# 2                6.9      4517
# 7                6.8       451
# 8                4.6        64
# 9                7.6        53
# 10               6.9       120
# ...              ...       ...
# 73849            8.4       365
# 73850            6.2         5
# 73851            6.2         6
# 73853            8.5         8
# 73855            6.5        11
#
# [36192 rows x 5 columns]

# %%
#creating variables for the z test
mu = gR.averagerating.mean() #population mean 
std = gR.averagerating.std()
count = len(gR[gR['genre']=='Music'])
alpha = 0.05
x_bar = gR[gR['genre']=='Music'].averagerating.mean() #sample mean

# %%
count
# Out:
# 308

# %%
x_bar
# Out:
# 7.241558441558439

# %%
#calculating the z vaule 
import math

z = (x_bar-mu)/(std/math.sqrt(count))
z
# Out:
# 9.723817414188014

# %%
#calculating the p value
import scipy.stats as stats
# Assign this to True or False
p = 1-stats.norm.cdf(z)
print(p)
print('alpha',alpha)
reject_null_hypothesis = 1-stats.norm.cdf(z)<alpha
# Out:
# 0.0
# alpha 0.05

# %%
reject_null_hypothesis
# Out:
# True
